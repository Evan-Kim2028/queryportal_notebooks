# %%
from dotenv import load_dotenv
import os
from subgrounds import Subgrounds

from datetime import datetime, timedelta

load_dotenv()

# LOAD Graph Network Subgraph ID and Playgrounds API Key
sg = Subgrounds(headers={"Playgrounds-Api-Key": os.environ['PG_KEY']})
univ3 = sg.load_subgraph(
f"https://api.playgrounds.network/v1/proxy/subgraphs/id/ELUcwgpm14LKPLrBRuVvPvNKHQ9HvwmtKgKSH6123cr7" 
)

# %%
univ3_qp = univ3.Query.swaps(
    orderBy=univ3.Swap.timestamp,   # or "tokenIn__symbol"
    orderDirection='desc',
    block = {'number_gte': 17315261},    # 17315261 is most recent block number as of May 22, 10:17am
    # block = {},
    where={    
    "pool_":  {"id": '0x5777d92f208679db4b9778590fa3cab3ac9e2168'},
    # 'timestamp_lte': int(datetime(2023, 5, 18).timestamp()),
    },
    first=100
)


print(sg.mk_request(univ3_qp).graphql)

# # Run query
df1 = sg.query_df(
    [
    univ3_qp.hash,
    univ3_qp.to,
    # univ3_qp.from,
    univ3_qp.pool.id,
    univ3_qp.pool.inputTokenBalances,
    univ3_qp.blockNumber,
    univ3_qp.timestamp,
    univ3_qp.amountIn,
    univ3_qp.tokenIn.symbol,
    univ3_qp.tokenOut.symbol,
    # univ3_qp.amountInUSD,
    univ3_qp.amountOut,
    # univ3_qp.amountOutUSD,
    ]
    )

print(df1.shape)
# Out:
# query {
#   x1b95d4fbb13547ba: swaps(first: 100, orderBy: timestamp, orderDirection: desc, where: {pool_: {id: "0x5777d92f208679db4b9778590fa3cab3ac9e2168"}}, block: {}) {
#     id
#     hash
#     logIndex
#     protocol {
#       id
#     }
#     to
#     from
#     blockNumber
#     timestamp
#     tokenIn {
#       id
#     }
#     amountIn
#     amountInUSD
#     tokenOut {
#       id
#     }
#     amountOut
#     amountOutUSD
#     pool {
#       id
#     }
#   }
# }
# (200, 10)

# %%
df1
# Out:
#                                             swaps_hash  \
# 0    0xaf639250b37190018a5a9161c31a06c398c65aa6e5b6...
# 1    0xaf639250b37190018a5a9161c31a06c398c65aa6e5b6...
# 2    0xde8b7b4bc735865aa8adc20ac1964d025574643e4c6a...
# 3    0xde8b7b4bc735865aa8adc20ac1964d025574643e4c6a...
# 4    0x8bf3345ab40b1486814535a0550995497e07c8c4f54d...
# ..                                                 ...
# 195  0xf6e83437911705234df58bdd52478f5bb60b91c5fe1d...
# 196  0x92fa57c6449d86e98a372c9f571d1502196bd66593b8...
# 197  0x92fa57c6449d86e98a372c9f571d1502196bd66593b8...
# 198  0xff5aa21f48366242c28ea3e906d16fb20c48e35c7df5...
# 199  0xff5aa21f48366242c28ea3e906d16fb20c48e35c7df5...
#
#                                        swaps_to  \
# 0    0x57bd8ab9ee90dc617e8a70b4b3e9fe29d6e408ec
# 1    0x57bd8ab9ee90dc617e8a70b4b3e9fe29d6e408ec
# 2    0xcebda550ff74f50e2b4941b2824c99aff9bda3a6
# 3    0xcebda550ff74f50e2b4941b2824c99aff9bda3a6
# 4    0xac35d74f53b7dc212ed9c2879e6598910bb7f712
# ..                                          ...
# 195  0xac35d74f53b7dc212ed9c2879e6598910bb7f712
# 196  0x69d91b94f0aaf8e8a2586909fa77a5c2c89818d5
# 197  0x69d91b94f0aaf8e8a2586909fa77a5c2c89818d5
# 198  0xb371dbe7f3de8b3fd9e310cf0074a8545987a2d1
# 199  0xb371dbe7f3de8b3fd9e310cf0074a8545987a2d1
#
#                                   swaps_pool_id swaps_pool_inputTokenBalances  \
# 0    0x5777d92f208679db4b9778590fa3cab3ac9e2168    49614675001810881816968407
# 1    0x5777d92f208679db4b9778590fa3cab3ac9e2168                58193117118969
# 2    0x5777d92f208679db4b9778590fa3cab3ac9e2168    49614675001810881816968407
# 3    0x5777d92f208679db4b9778590fa3cab3ac9e2168                58193117118969
# 4    0x5777d92f208679db4b9778590fa3cab3ac9e2168    49614675001810881816968407
# ..                                          ...                           ...
# 195  0x5777d92f208679db4b9778590fa3cab3ac9e2168                58193117118969
# 196  0x5777d92f208679db4b9778590fa3cab3ac9e2168    49614675001810881816968407
# 197  0x5777d92f208679db4b9778590fa3cab3ac9e2168                58193117118969
# 198  0x5777d92f208679db4b9778590fa3cab3ac9e2168    49614675001810881816968407
# 199  0x5777d92f208679db4b9778590fa3cab3ac9e2168                58193117118969
#
#      swaps_blockNumber  swaps_timestamp           swaps_amountIn  \
# 0             17315577       1684767563               1320483865
# 1             17315577       1684767563               1320483865
# 2             17315571       1684767491             108968377059
# 3             17315571       1684767491             108968377059
# 4             17315558       1684767335               4257976937
# ..                 ...              ...                      ...
# 195           17313557       1684742963               5263541639
# 196           17313544       1684742807    633358081469012592568
# 197           17313544       1684742807    633358081469012592568
# 198           17313505       1684742339  78810756158250022552167
# 199           17313505       1684742339  78810756158250022552167
#
#     swaps_tokenIn_symbol swaps_tokenOut_symbol           swaps_amountOut
# 0                   USDC                   DAI    1320328650169534580901
# 1                   USDC                   DAI    1320328650169534580901
# 2                   USDC                   DAI  108955590904744468150958
# 3                   USDC                   DAI  108955590904744468150958
# 4                   USDC                   DAI    4257478210472497979406
# ..                   ...                   ...                       ...
# 195                 USDC                   DAI    5262904458793284437263
# 196                  DAI                  USDC                 633308076
# 197                  DAI                  USDC                 633308076
# 198                  DAI                  USDC               78804545470
# 199                  DAI                  USDC               78804545470
#
# [200 rows x 10 columns]
